# %%
import pandas as pd
import requests
import csv
import json

# %%
df = pd.read_csv("C:/Users/ayush/Desktop/Scratch_user.csv")

# %%
df.reset_index(drop=True)
df.head()
# Out:
#   Field1_Text_Text
# 0   CrystalKeeper7
# 1           Dhilly
# 2   ElectricGalaxy
# 3        Hobson-TV
# 4          DANISON

# %%
username=list()

# %%
len(df.Field1_Text_Text)
# Out:
# 148

# %%
for i in df.Field1_Text_Text:
    username.append(i)

# %%
len(username)
# Out:
# 148

# %%
api_base_url="https://api.scratch.mit.edu"
api_endpoint_users="/users/"
api_endpoint_projects="/projects"

# %%
print(username)
# Out:
# ['CrystalKeeper7', 'Dhilly', 'ElectricGalaxy', 'Hobson-TV', 'DANISON', 'theChAOTiC', 'Rosyda', 'eunice0913', 'Im_theEG', 'FunnyAnimatorJimTV', 'AndrewDai', 'Good-Website', 'caterpillarstyle', 'Daria_Shu', 'DISHDASH_TEST', 'Qtyann', 'gumboygames', 'NilsTheBest', 'MJM3', 'remixsuper', 'Canarysong', 'lengthhead1', 'Greninja714', 'FlyFree-', 'Ghostxiaomo', 'atomicmagicnumber', 'Walle10-0', 'MisterDoughnut', 'qucchia', 'haniamatuszyk', 'JWhandle', 'ceebee', 'xXskullXcrusherXx', 'FastFunnyz', 'LifeExplained', 'Derpy_Donut', 'ToadfanSchool', 'Blossom_Crowfeather', 'pizzzapi', 'superluigi16', 'Funnygummywarrior', 'adazem009', 'LeiIani', '--Eternity--', 'ArrowCinderFeather', 'huntedskelly', 'Rainbow_Reality', '23ScratchMan', 'StickmantheStickman', '-Imagineer-', 'TopRamenNoodles', 'Hormovitis', 'ivypool2', 'GaMMeMaker007', 'BookTV', 'colinmacc', 'CHICALOVEPIZZA', '-loliipop-', 'Will_Wam', 'meurpTV', 'BadgeheartIsBestShip', 'Bcow', 'MistCat', 'SCRACO65', 'nameIess', 'crazyweasle123', 'cutupuss
# ...

# %%
dataoriginal=pd.DataFrame(columns=['username', 'idus', 'titleus','histusc','histusm','histuss','stview','stlove','stfav','scomment','stremix'])

# %%
dataoriginal
# Out:
# Empty DataFrame
# Columns: [username, idus, titleus, histusc, histusm, histuss, stview, stlove, stfav, scomment, stremix]
# Index: []

# %%
valre=('id','title','history','stats')

# %%
usernameo=list()
idus=list()
titleus=list()
histusc=list()
histusm=list()
histuss=list()
stview=list()
stlove=list()
stfav=list()
stremix=list()
scomment=list()

# %%
for name in username:
    api_endpoint_username= name
    username_str= str(api_endpoint_username)
    seed_url=api_base_url+api_endpoint_users+username_str+api_endpoint_projects
    response= requests.get(seed_url)
    response_content=json.loads(response.content)
    for d in response_content:
        usernameo.append(name)
        idus.append(d['id'])
        titleus.append(d['title'])
        histusc.append(d['history']['created'])
        histusm.append(d['history']['modified'])
        histuss.append(d['history']['shared'])
        stview.append(d['stats']['views'])
        stlove.append(d['stats']['loves'])
        stfav.append(d['stats']['favorites'])
        stremix.append(d['stats']['remixes'])
        scomment.append(d['stats']['comments'])

# %%
dataoriginal['username']=usernameo
dataoriginal['idus']=idus
dataoriginal['titleus']=titleus
dataoriginal['histusc']=histusc
dataoriginal['histusm']=histusm
dataoriginal['histuss']=histuss
dataoriginal['stview']=stview
dataoriginal['stlove']=stlove
dataoriginal['stfav']=stfav
dataoriginal['scomment']=scomment
dataoriginal['stremix']=stremix
# , 'idus', 'titleus','histusc','histusm','histuss','stview','stlove','stfav','scomment','stremix'])

# %%
dataoriginal
# Out:
#             username       idus  \
# 0     CrystalKeeper7  138106843
# 1     CrystalKeeper7  139445735
# 2     CrystalKeeper7  140097116
# 3     CrystalKeeper7  140185501
# 4     CrystalKeeper7  140637333
# 5     CrystalKeeper7  141260437
# 6     CrystalKeeper7  141496768
# 7     CrystalKeeper7  142366466
# 8     CrystalKeeper7  142664899
# 9     CrystalKeeper7  142675446
# 10    CrystalKeeper7  143663274
# 11    CrystalKeeper7  147594322
# 12    CrystalKeeper7  148009778
# 13    CrystalKeeper7  148055669
# 14    CrystalKeeper7  148111327
# 15    CrystalKeeper7  149822716
# 16    CrystalKeeper7  150638265
# 17    CrystalKeeper7  150917863
# 18    CrystalKeeper7  151527300
# 19    CrystalKeeper7  153664892
# 20            Dhilly   13455794
# 21            Dhilly   14369011
# 22            Dhilly   14370939
# 23            Dhilly   14393506
# 24            Dhilly   14394359
# 25            Dhilly   14767034
# 26            Dhilly   16221788
# 27            Dhilly   18016539
# ...

# %%
dataoriginal.to_csv('extractedfile.csv')

# %%
pwd
# Out:
# 'C:\\Users\\ayush'

# %%
usernameo.append(name)
idus.append(d['id'])
titleus.append(d['title'])
histus.append(d['history']['created'])
histus.append(d['history']['modified'])
histus.append(d['history']['shared'])
stview.append(d['stats']['views'])
stlove.append(d['stats']['loves'])
stfav.append(d['stats']['favorites'])
stremix.append(d['stats']['remixes'])
scomment.append(d['stats']['comments'])
print(len(usernameo))
print(len(idus))
print(len(titleus))
print(len(histus))
print(len())
print(len())
print(len())
print(len())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-346-6205f6fa65c9> in <module>
# ----> 1 print(len())
#       2 print(len())
#       3 print(len())
#       4 print(len())
#
# TypeError: len() takes exactly one argument (0 given)

# %%
dataoriginal.insert(3,'asdfads','1031130198')

# %%
# Out:
# Empty DataFrame
# Columns: [username, idus, titleus, histus, stview, stlove, stfav, stremix]
# Index: []

# %%
dataoriginal
# Out:
#    username  idus titleus histus stview stlove stfav stremix
# 0        20    10     NaN    NaN    NaN    NaN   NaN     NaN
# 1        30    20     NaN    NaN    NaN    NaN   NaN     NaN
# 2        40    30     NaN    NaN    NaN    NaN   NaN     NaN

# %%
for i in response_content:
# Out:
# 289401455
# 289401888
# 293103551
# 299066367
# 299452822
# 300250239
# 308107963
# 309774041
# 317489796

# %%
valre=('id','title','history','stats')
count=0
if count<=len(valre):
    print(count)
    count=count+1
# Out:
# 0

# %%
for i in response_content:
#     this is extraction 
    idus=i['id']
    titleus=i['title']
    histusi=['history']
    statsus=i['stats']ss

# %%
statsus
# Out:
# {'views': 163, 'loves': 20, 'favorites': 7, 'comments': 25, 'remixes': 0}

# %%
# Out:
# dict

# %%
type(response_content)
# Out:
# list

# %%
len(response_content)
# Out:
# 9

# %%
a=response_content[8]

# %%
a['stats']
# Out:
# {'views': 163, 'loves': 20, 'favorites': 7, 'comments': 25, 'remixes': 0}

# %%
for l in response_content:
    l.remove(author)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-3c6f15232702> in <module>
#       1 for l in response_content:
# ----> 2     l.remove(author)
#
# AttributeError: 'dict' object has no attribute 'remove'

# %%
for key, value in response_content[0].items():
    print(key)
# Out:
# id
# title
# instructions
# visibility
# public
# comments_allowed
# is_published
# author
# image
# images
# history
# stats
# remix

# %%
for d in response_content:
    del d['visibility']
    del d['public']
    del d['comments_allowed']
    del d['is_published']
    del d['author']
    del d['image']
    del d['images']

# %%
response_content
# Out:
# [{'id': 138106843,
#   'title': 'Geometry Dash v3.0',
#   'description': 'Thank you griffpatch for transferring the game to scratch so I could play it and remix it. Please leave it in the comments if you want me to change a level. When this game hits 100 views I will remix a level and make it better. :0\n ',
#   'instructions': "Space, up, w, or clicking the mouse is to jump. I put in some extra obstacles to make some parts harder. Hope you guys have fun. So sorry the high score is glitching I don't know why but I'm trying to find out.",
#   'visibility': 'visible',
#   'public': True,
#   'comments_allowed': True,
#   'is_published': True,
#   'author': {'id': 20559872,
#    'scratchteam': False,
#    'history': {'joined': '1900-01-01T00:00:00.000Z'},
#    'profile': {'id': None,
#     'images': {'90x90': 'https://cdn2.scratch.mit.edu/get_image/user/20559872_90x90.png?v=',
#      '60x60': 'https://cdn2.scratch.mit.edu/get_image/user/20559872_60x60.png?v=',
# ...

# %%
count=0
tesa=list()
for d in response_content:
    print(d['id'])
    count=count+1
    tesa.append(d['id'])
#     tesa=tesa.append(lvr)
print(tesa)
# Out:
# 138106843
# 139445735
# 140097116
# 140185501
# 140637333
# 141260437
# 141496768
# 142366466
# 142664899
# 142675446
# 143663274
# 147594322
# 148009778
# 148055669
# 148111327
# 149822716
# 150638265
# 150917863
# 151527300
# 153664892
# 20

# %%
print(tesa)
# Out:
# [138106843, 139445735, 140097116, 140185501, 140637333, 141260437, 141496768, 142366466, 142664899, 142675446, 143663274, 147594322, 148009778, 148055669, 148111327, 149822716, 150638265, 150917863, 151527300, 153664892]
